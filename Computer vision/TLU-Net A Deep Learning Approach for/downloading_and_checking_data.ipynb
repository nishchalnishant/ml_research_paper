# %%
import pandas as pd
import numpy as np
import os 
import shutil
from glob import glpb 
import random
from pil import Image

# %%
pip install Pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# getting data from the kaggle website using kaggle website 
# !pip install kaggle --upgrade

# %%
# !kaggle competitions download -c severstal-steel-defect-detection -p data

# %%
DATA=".\data"

# %%
# etracting the zip files
for i in range(len(os.listdir('.\data'))):
    if (os.listdir('.\data')[i][-4:]=='.zip'):
        shutil.unpack_archive(os.path.join(DATA,os.listdir(".\data")[i]), '.\data')

# %%
# now we are going to visualize some images and plot them
train=os.path.join(DATA,"train_images")
test=os.path.join(DATA,'test_images')
train_data=pd.read_csv('data/train.csv')

# %%
train_data.head()
# Out:
#          ImageId  ClassId                                      EncodedPixels
# 0  0002cc93b.jpg        1  29102 12 29346 24 29602 24 29858 24 30114 24 3...
# 1  0007a71bf.jpg        3  18661 28 18863 82 19091 110 19347 110 19603 11...
# 2  000a4bcdd.jpg        1  37607 3 37858 8 38108 14 38359 20 38610 25 388...
# 3  000f6bf48.jpg        4  131973 1 132228 4 132483 6 132738 8 132993 11 ...
# 4  0014fce06.jpg        3  229501 11 229741 33 229981 55 230221 77 230468...

# %%
train_data.describe()
# Out:
#            ClassId
# count  7095.000000
# mean      2.825229
# std       0.789279
# min       1.000000
# 25%       3.000000
# 50%       3.000000
# 75%       3.000000
# max       4.000000

# %%
a=pd.DataFrame(train_data.ImageId.value_counts())

# %%
train_data.ImageId.value_counts()
# Out:
# db4867ee8.jpg    3
# ef24da2ba.jpg    3
# b27127d1d.jpg    2
# d57873aaa.jpg    2
# 2c4b101db.jpg    2
#                 ..
# 21a0c7160.jpg    1
# 12471d0d5.jpg    1
# 79d28bbe8.jpg    1
# bb6c5d50f.jpg    1
# 17b384c3e.jpg    1
# Name: ImageId, Length: 6666, dtype: int64

# %%
rand=random.choice(os.listdir(train))

print(train_data.ClassId[train_data['ImageId']==rand])
Image.open(os.path.join(train, rand))
# Out:
# Series([], Name: ClassId, dtype: int64)
# <pil.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x256 at 0x234F5F07A88>

# %%
train_data[train_data.ImageId==rand]
# Out:
# Empty DataFrame
# Columns: [ImageId, ClassId, EncodedPixels]
# Index: []

# %%
train and train_data
# Out:
# '.\\data\\train_images'

# %%
# 6666 unique train data in csv  these are the images which has at least one defective region 
# rest all images dont have any defect
len(train_data.ImageId.unique())
# Out:
# 6666

# %%
len(set(os.listdir(train)))       # toaal train images
# Out:
# 12568

# %%
len(set(os.listdir(test)))        # total test images
# Out:
# 5506
