# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os 
import shutil
from glob import glob
import random
import PIL

# %%
pip install Pillow==2.2.1
# Out:
# ...
#   Running setup.py clean for Pillow
# Failed to build Pillow
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 8.0.1
#     Uninstalling Pillow-8.0.1:
#       Successfully uninstalled Pillow-8.0.1
#     Running setup.py install for Pillow: started
#     Running setup.py install for Pillow: finished with status 'error'
#   Rolling back uninstall of Pillow
#   Moving to c:\users\nishchal\miniconda3\envs\tf-packt-gpu\lib\site-packages\pil\
#    from c:\users\nishchal\miniconda3\envs\tf-packt-gpu\lib\site-packages\~il
#   Moving to c:\users\nishchal\miniconda3\envs\tf-packt-gpu\lib\site-packages\pillow-8.0.1.dist-info\
#    from c:\users\nishchal\miniconda3\envs\tf-packt-gpu\lib\site-packages\~illow-8.0.1.dist-info
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
# ...

# %%
# !pip install cv2
# Out:
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2

# %%
# getting data from the kaggle website using kaggle website 
# !pip install kaggle --upgrade
# Out:
# ...
#   Using cached python-slugify-4.0.1.tar.gz (11 kB)
# ...
#   Using cached text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# ...
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73057 sha256=a4f929de3477a416ecfff1b9f55c60082657dc716b8b4b91111004a1d1106da1
#   Stored in directory: c:\users\nishchal\appdata\local\pip\cache\wheels\62\d6\58\5853130f941e75b2177d281eb7e44b4a98ed46dd155f556dc5
# ...
#   Created wheel for python-slugify: filename=python_slugify-4.0.1-py2.py3-none-any.whl size=6772 sha256=992c0d9e7f0043033577928f2ab7f8f6303241d1032a93051de710eae2888ce1
#   Stored in directory: c:\users\nishchal\appdata\local\pip\cache\wheels\48\1b\6f\5c1cfab22eacbe0095fc619786da6571b55253653c71324b5c
# Successfully built kaggle python-slugify
# ...
# ^C

# %%
# !kaggle competitions download -c severstal-steel-defect-detection -p data
# Out:
# ^C

# %%
DATA=".\data"

# %%
for i in range(len(os.listdir('.\data'))):
    if (os.listdir('.\data')[i][-4:]=='.zip'):
        shutil.unpack_archive(os.path.join(DATA,os.listdir(".\data")[i]), '.\data')

# %%
# now we are going to visualize some images and plot them
train=os.path.join(DATA,"train_images")
test=os.path.join(DATA,'test_images')
train_data=pd.read_csv('data/train.csv')

# %%
train_data.ClassId[train_data['ImageId']==rand]
rand
# Out:
# 'c98cafcf4.jpg'

# %%
rand=random.choice(os.listdir(train))

print(train_data.ClassId[train_data['ImageId']==rand])
PIL.Image.open(os.path.join(train, rand))
# Out:
# Series([], Name: ClassId, dtype: int64)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x256 at 0x23E65B189C8>

# %%
rand
# Out:
# '0d1e0ae6d.jpg'

# %%
set(train_data.ImageId==rand)
# Out:
# {False}
