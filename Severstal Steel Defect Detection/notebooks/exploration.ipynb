# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os

# %%
IMG_PATH="..\input"
TRAIN_PATH=os.path.join(IMG_PATH,"train_images")
DATA_PATH=os.path.join(IMG_PATH,"train.csv")

# %%
TRAIN_PATH
# Out:
# '..\\input\\train_images'

# %%
DATA_PATH
# Out:
# '..\\input\\train.csv'

# %%
df=pd.read_csv(DATA_PATH)

# %%
""" the csv file has the image name with the class of deffect in that image , in addition to that we have the encoded pixels in  which those defects were present """

df.head()
# Out:
#          ImageId  ClassId                                      EncodedPixels
# 0  0002cc93b.jpg        1  29102 12 29346 24 29602 24 29858 24 30114 24 3...
# 1  0007a71bf.jpg        3  18661 28 18863 82 19091 110 19347 110 19603 11...
# 2  000a4bcdd.jpg        1  37607 3 37858 8 38108 14 38359 20 38610 25 388...
# 3  000f6bf48.jpg        4  131973 1 132228 4 132483 6 132738 8 132993 11 ...
# 4  0014fce06.jpg        3  229501 11 229741 33 229981 55 230221 77 230468...

# %%
df.shape # training images are 7095 in numbers
# Out:
# (7095, 3)

# %%
"""this data is really skewed , so it would be advisable to use the stratified k fold validation """

df.ClassId.value_counts()
# Out:
# 3    5150
# 1     897
# 4     801
# 2     247
# Name: ClassId, dtype: int64

# %%
len(df.EncodedPixels[1])/4  # the value in the encoded pixels is interms of x1,x2,y1,y2
# Out:
# 97.0

# %%
a=os.path.join(TRAIN_PATH,all_images[np.random.choice(12568)])
img = plt.imread(a)
plt.imshow(img)
print(a)
# Out:
# ..\input\train_images\1e5f88c2c.jpg
# ..\input\train_images\a5aa4829b.jpg
# ..\input\train_images\9efb4b561.jpg
# ..\input\train_images\feb959e50.jpg
# ..\input\train_images\679af1ef8.jpg
# ..\input\train_images\f2aa8fa9e.jpg
# ..\input\train_images\3153ea0ef.jpg
# ..\input\train_images\5fa66ef18.jpg
# ..\input\train_images\445dfb2ce.jpg
# ..\input\train_images\1ee9359c6.jpg

# %%
w=30
h=15
fig=plt.figure(figsize=(15, 15))
columns = 4
rows = 5
for i in range(1, columns*rows +1):
    a=os.path.join(TRAIN_PATH,all_images[np.random.choice(12568)])
    img = plt.imread(a)
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()
